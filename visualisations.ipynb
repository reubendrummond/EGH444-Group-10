# %%
from visualise_model_performance import visualise_model_performance
from src.visualization.plot_training import plot_training_curves, plot_combined_metrics, load_training_history

# %%
history = load_training_history("checkpoints/unet_mobilenet/best2.pth")
plot_combined_metrics(history);
plot_training_curves(history);

# %%
visualise_model_performance(checkpoint_path="checkpoints/unet_mobilenet/best2.pth", 
                            samples=6,
                            split='test');
# Out:
# 🔧 Using device: mps
# Loading checkpoint from: checkpoints/unet_mobilenet/best2.pth
# Auto-detected model type: mobilenet
# Using MobileNetV3-Small with random initialization
# UNet-MobileNetV3-SMALL initialized:
#   Total parameters: 2,361,960
#   Trainable parameters: 2,361,960
#   Encoder channels: [16, 16, 24, 48, 96]
# ✓ Model loaded successfully
#   - Model type: mobilenet
#   - Classes: 40
#   - Input modalities: RGB=True, Depth=False
# ✅ Model loaded successfully!
# ✓ Created test data loader with 20 samples
# ✅ Data loader created with 20 samples
# 🎨 Creating visualization with 6 samples...
# ✅ Visualization complete!
